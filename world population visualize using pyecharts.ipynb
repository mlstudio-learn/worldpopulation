# %%
import pandas as pd

from pyecharts.charts import Map,Geo
from pyecharts import options as opts, render
from pyecharts.globals import ThemeType

# %%
dataset=pd.read_csv("country wise population.csv")

# %%
country=list(dataset['Country Name'])
population=list(dataset['2019'])

# %%
list1 = [[country[i],population[i]] for i in range(len(country))]
map_1 = Map(init_opts=opts.InitOpts(width="1000px", height="460px",theme=ThemeType.ROMANTIC))
map_1.add('Total Population', list1,maptype='world',is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(),
 title_opts=opts.TitleOpts(title="World Population",
 subtitle='Till 2016',pos_left='center',padding=0,item_gap=2,
 title_textstyle_opts= opts.TextStyleOpts(color='darkblue',
 font_weight='bold',font_family='Courier New',
 font_size=30),subtitle_textstyle_opts= opts.TextStyleOpts(color='grey',
 font_weight='bold',font_family='Courier New',
 font_size=13)),legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic'
#         }
#     });
# </script>
#
#         <div id="a386ad96d5504e469941dbeec54fbaac" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'romantic'], function(echarts) {
#                 var chart_a386ad96d5504e469941dbeec54fbaac = echarts.init(
#                     document.getElementById('a386ad96d5504e469941dbeec54fbaac'), 'romantic', {renderer: 'canvas'});
#                 var option_a386ad96d5504e469941dbeec54fbaac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Aruba",
#                     "value": 106314.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 38041754.0
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 31825295.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 2854191.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 77142.0
#                 },
#                 {
#                     "name": "Arab World",
#                     "value": 427870270.0
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 9770529.0
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 44938712.0
#                 },
#                 {
#                     "name": "Armenia",
#                     "value": 2957731.0
#                 },
#                 {
#                     "name": "American Samoa",
#                     "value": 55312.0
#                 },
#                 {
#                     "name": "Antigua and Barbuda",
#                     "value": 97118.0
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 25364307.0
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 8877067.0
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 10023318.0
#                 },
#                 {
#                     "name": "Burundi",
#                     "value": 11530580.0
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 11484055.0
#                 },
#                 {
#                     "name": "Benin",
#                     "value": 11801151.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 20321378.0
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 163046161.0
#                 },
#                 {
#                     "name": "Bulgaria",
#                     "value": 6975761.0
#                 },
#                 {
#                     "name": "Bahrain",
#                     "value": 1641172.0
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 389482.0
#                 },
#                 {
#                     "name": "Bosnia and Herzegovina",
#                     "value": 3301000.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 9466856.0
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 390353.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": 63918.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 11513100.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 211049527.0
#                 },
#                 {
#                     "name": "Barbados",
#                     "value": 287025.0
#                 },
#                 {
#                     "name": "Brunei Darussalam",
#                     "value": 433285.0
#                 },
#                 {
#                     "name": "Bhutan",
#                     "value": 763092.0
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 2303697.0
#                 },
#                 {
#                     "name": "Central African Rep.",
#                     "value": 4745185.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 37589262.0
#                 },
#                 {
#                     "name": "Central Europe and the Baltics",
#                     "value": 102378579.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 8574832.0
#                 },
#                 {
#                     "name": "Channel Islands",
#                     "value": 172259.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 18952038.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 1397715000.0
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 25716544.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 25876380.0
#                 },
#                 {
#                     "name": "Dem. Rep. Congo",
#                     "value": 86790567.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 5380508.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 50339443.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 850886.0
#                 },
#                 {
#                     "name": "Cabo Verde",
#                     "value": 549935.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 5047561.0
#                 },
#                 {
#                     "name": "Caribbean small states",
#                     "value": 7401381.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 11333483.0
#                 },
#                 {
#                     "name": "Curacao",
#                     "value": 157538.0
#                 },
#                 {
#                     "name": "Cayman Islands",
#                     "value": 64948.0
#                 },
#                 {
#                     "name": "Cyprus",
#                     "value": 1198575.0
#                 },
#                 {
#                     "name": "Czech Republic",
#                     "value": 10669709.0
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 83132799.0
#                 },
#                 {
#                     "name": "Djibouti",
#                     "value": 973560.0
#                 },
#                 {
#                     "name": "Dominica",
#                     "value": 71808.0
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 5818553.0
#                 },
#                 {
